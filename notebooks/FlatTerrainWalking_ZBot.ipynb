# %% [markdown]
# <a href="https://colab.research.google.com/github/pravsels/mujoco_playground/blob/master/notebooks/FlatTerrainWalking_ZBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Create conda environment with python 3.12

# %%
# !pip install -q condacolab

# %%
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...

# %%
# %%capture output
# !conda create -y -n py312 python=3.12
# !source activate py312 && python --version

# %% [markdown]
# ### Clone `mujoco_playground` repo and install

# %%
# !git clone https://github.com/kscalelabs/mujoco_playground.git
# Out:
# Cloning into 'mujoco_playground'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (125/125), done.
# remote: Total 170 (delta 68), reused 137 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (170/170), 12.32 MiB | 32.34 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
cd mujoco_playground/
# Out:
# /content/mujoco_playground

# %%
# %%capture output
# !source activate py312 && pip install -e .

# %%
# !source activate py312 && pip install colorlogging

# %%
# %%capture output
# !source activate py312 && pip install --upgrade "jax[cuda12]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html

# %%
# !source activate py312 && python -c "import jax; print(jax.devices())"
# expect CudaDevice
# Out:
# [CudaDevice(id=0)]

# %% [markdown]
# ### Run training script for Zbot

# %%
# !source activate py312 && python playground/zbot/runner.py --env ZbotJoystickFlatTerrain --debug --save-model
# Out:
# INFO:2025-03-12 13:47:46,286:jax._src.xla_bridge:924: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
#   INFO  2025-03-12 13:47:46 [jax._src.xla_bridge] Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:2025-03-12 13:47:46,288:jax._src.xla_bridge:924: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
#   INFO  2025-03-12 13:47:46 [jax._src.xla_bridge] Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# ...
